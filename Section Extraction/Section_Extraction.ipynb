# %%
import spacy
from spacy.vectors import Vectors
import os
import pandas as pd
import numpy as np
nlp = spacy.load('en_core_web_sm')
vectors = Vectors(shape=(10000, 300))
nlp.vocab.vectors = vectors
print(nlp.vocab.vectors.shape)
import re
re_c = re.compile(r'\w+')
# Out:
# (10000, 300)

# %%
# switch for debug
flag_print = True

# switch to clear existing data
flag_clear = True

#threshold value for determining section
threshold = 0.5

# %%
# to get extract sections from the resume -- add or remove from  'similar_to' accordingly
similar_to = {
    'edu' : ['education', 'study', 'academics', 'institute', 'school', 'college'],
    'exp' : ['job', 'internship', 'training', 'research', 'career', 'profession', 'role'
             'project', 'responsibility', 'description', 'work experience', 'workshop', 'conference'],
    'skill' : ['skill', 'languages', 'technology', 'framework', 'tools', 'database'],
    'extra' : ['introduction', 'intro', 'achievement', 'hobby', 'links', 'additional', 
               'personal', 'award', 'objective', 'miscellaneous', 'interest']
}

list_of_sections = similar_to.keys()

# to bring similar_words to their normal forms
for section in list_of_sections:
    new_list = []
    
    for word in similar_to[section]:
        docx = nlp(word)
        new_list.append(docx[0].lemma_)
        
    if flag_print:
        print(section, new_list)
        
    similar_to[section] = new_list
# Out:
# extra ['introduction', 'intro', 'achievement', 'hobby', 'link', 'additional', 'personal', 'award', 'objective', 'miscellaneous', 'interest']
# exp ['job', 'internship', 'training', 'research', 'carrer', 'profession', 'roleproject', 'responsibility', 'description', 'work', 'workshop', 'conference']
# skill ['skill', 'language', 'technology', 'framework', 'tool', 'database']
# edu ['education', 'study', 'academic', 'institute', 'school', 'college']

# %%
# function to remove unnecessary symbols and stopwords 
def modify(word):
    try:
        symbols = '''~'`!@#$%^&*)(_+-=}{][|\:;",./<>?'''
        mod_word = ''
        
        for char in word:
            if (char not in symbols):
                mod_word += char.lower()

        docx = nlp(mod_word)

        if (len(mod_word) == 0 or docx[0].is_stop):
            return None
        else:
            return docx[0].lemma_
    except:
        return None # to handle the odd case of characters like 'x02', etc.
    
if flag_print:
    test_words = ['Hello!!', '.,<>', 'India', 'of', '..freedoM..', 'e-mail']
    
    for word in test_words:
        print(word, '--returned-->', modify(word))
# Out:
# Hello!! --returned--> hello
# .,<> --returned--> None
# India --returned--> india
# of --returned--> None
# ..freedoM.. --returned--> freedom
# e-mail --returned--> email

# %%
# utility function to skip line when no alphabet present
def is_empty(line):
    for c in line:
        if (c.isalpha()):
            return False
    return True
      
if flag_print:
    test_words = ['.', '<.>', 'Speak', 'out', '"Eric"', 'freemail...']
    
    for word in test_words:
        print(word, '--returned-->', is_bad(word))
# Out:
# . --returned--> True
# <.> --returned--> True
# Speak --returned--> False
# out --returned--> False
# "Eric" --returned--> False
# freemail... --returned--> False

# %%
dict_of_data_series = {}
flag_print = False

for file_name in os.listdir(os.getcwd()+'/CVs'):
    if flag_print:
        print('\n')
        print('*'*25) 
        print(file_name) 
        print('*'*25) 
        
    main_file_handler = open('CVs/'+file_name, 'r', encoding='latin-1')  
    previous_section  = 'extra'
    
    curr_data_series = pd.Series([""]*len(list_of_sections), index=list_of_sections)
                   
    for line in main_file_handler:
        # skip line if empty
        if (len(line.strip()) == 0 or is_empty(line)):
            continue
                
        # processing next line
        list_of_words_in_line = re_c.findall(line)
        list_of_imp_words_in_line  = []
        
        for i in range(len(list_of_words_in_line)):
            modified_word = modify(list_of_words_in_line[i])
            
            if (modified_word):
                list_of_imp_words_in_line.append(modified_word)

        curr_line = ' '.join(list_of_imp_words_in_line)
        doc = nlp(curr_line)
        section_value = {}
            
        # initializing section values to zero
        for section in list_of_sections:
            section_value[section] = 0.0
        section_value[None] = 0.0
            
        # updating section values    
        for token in doc:
            for section in list_of_sections:
                for word in similar_to[section]:
                    word_token = doc.vocab[word]
                    section_value[section] = max(section_value[section], float(word_token.similarity(token)))

        # determining the next section based on section values and threshold
        most_likely_section = None
        for section in list_of_sections:
            #print '>>', section, section_value[section]
            if (section_value[most_likely_section] < section_value[section] and section_value[section] > threshold):
                most_likely_section = section
            
        # updating the section
        if (previous_section != most_likely_section and most_likely_section is not None):
            previous_section = most_likely_section
                

        # writing data to the pandas series
        try:
            docx = nlp(line)
        except:
            continue  # to handle the odd case of characters like 'x02', etc.
        mod_line = ''
        for token in docx:
            if (not token.is_stop):
                mod_line += token.lemma_ + ' '
        
        curr_data_series[previous_section] += mod_line
            
    dict_of_data_series[file_name] = curr_data_series
    if flag_print:
        print(curr_data_series)
    main_file_handler.close()
    
data_frame = pd.DataFrame(dict_of_data_series)
data_frame.to_csv('prc_data.csv', sep='\t')
#data_frame.head()

# %%
data_frame.head()
# Out:
#                                                .DS_Store  \
# %...
# exp
# skill
# edu
#
#                                                      cv1  \
# extra  mahboob alam \n software developer - dynamix i...
# exp    -PRON- want work progressive organization -PRO...
# skill  skill \n html5 ( 2 year ) , css3 ( 2 year ) , ...
# edu    education \n pg - diploma advance software dev...
#
#                                                     cv10  \
# extra      deepali chaudhari \n mumbai , maharashtra \n
# exp    work experience \n team member(software develo...
# skill  be information technology \n nagpur university...
# edu                                        education \n
#
#                                                    cv100  \
# extra  ramakrishnan k \n cuddalore , tamil nadu \n mc...
# exp    -PRON- hard worker , enthusiastic , responsibl...
# skill  skill \n communication skills . \n fast learne...
# edu    education \n be \n dhanalakshmi srinivasan col...
#
#                                                    cv101  \
# extra  jayaprakash andamuthu \n application developer...
# exp    â¢ with good knowledge develop application an...
# skill  b.sc computer technology \n diploma informatio...
# edu    education \n kongu arts science college erode ...
#
#                                                    cv102  \
# extra  rajeev gupta \n additional information \n * se...
# exp    * currently work cognizant technology solution...
# skill  application developer - cognizant technology s...
# edu    education \n b.e. engineering \n bengal engine...
#
#                                                    cv103  \
# extra  alaguraj ramachandran \n android application d...
# exp    work experience \n application application dev...
# skill  skill \n â¢ operating system : windows 10 ubu...
# edu    education \n b.e computer science engg \n vel ...
#
#                                                    cv104  \
# extra  aiswarya chandrasekaran \n application develop...
# exp    â¢ good communication interpersonal skill eas...
# skill  â¢ primary skill constitute cobol , jcl , db2...
# edu    education \n bachelor of engineering electroni...
#
#                                                    cv105  \
# extra  ashay jain \n application developer \n bhopal ...
# exp    â¢ currently work application developer atos ...
# skill  â¢ expertise java , groovy language related f...
# edu
#
#                                                    cv106  \
# extra  heena patel \n surat , gujarat \n contribute o...
# exp    work experience \n iphone application develope...
# skill  to pursue growth experience field information ...
# edu
#
#                              ...                          \
# extra                        ...
# exp                          ...
# skill                        ...
# edu                          ...
#
#                                                     cv90  \
# extra  karthikeyan p \n â¢ link end datum tool end ....
# exp    senior research analyst relationship science (...
# skill  â¢ validate information give island ( factset...
# edu    education \n bachelor engineering computer sci...
#
#                                                     cv91  \
# extra  bishvajit bakshi \n bangalore , karnataka \n a...
# exp    work experience \n data analyst \n in college ...
# skill  skill \n microsoft excel , microsoft ppt , mic...
# edu    education \n m.sc . statistics \n university a...
#
#                                                     cv92  \
# extra  darpana nandy \n executive , data science - th...
# exp    work experience \n executive , data science \n...
# skill  skill \n data analysis ( less 1 year ) , data ...
# edu    india statistical institute - kolkata , west b...
#
#                                                     cv93  \
# extra  harish venkataraman \n bangalore , karnataka \...
# exp    work experience \n data science intern \n talv...
# skill  tool - nlp , elasticsearch , python , alchemyl...
# edu    education \n b.e. information science \n dayan...
#
#                                                     cv94  \
# extra  sharad kakran \n link \n https://github.com/sh...
# exp           work experience \n data science intern \n
# skill  cappius technologies - hyderabad , telangana \...
# edu    analyzed customer transaction behavior shoppin...
#
#                                                     cv95  \
# extra  ketan bhatheja \n bangalore , karnataka \n - u...
# exp    work experience \n data science & analytics , ...
# skill  - require data gathering database issue report...
# edu    education \n m.sc . economics \n madras school...
#
#                                                     cv96  \
# extra  rahul vhayaskar \n dhule , maharashtra \n link...
# exp    work experience \n android application develop...
# skill  ecs technologies pvt . ltd. - pune , maharasht...
# edu    education \n b.e engineering \n north maharash...
#
#                                                     cv97  \
# extra  babli bisht \n android application developer h...
# exp    â¢ to work key player challenging creative en...
# skill  interglobe technologies - gurgaon , haryana \n...
# edu    education \n mtech electronics ( instrumentati...
#
#                                                     cv98  \
# extra  reshma patil \n jr. ios application developer ...
# exp    work experience \n jr. ios application develop...
# skill  technical skills:- \n tool : xcode ( 5 + ) \n ...
# edu    education \n b.e \n indira college engineering...
#
#                                                     cv99
# extra  rajith r \n web application developer \n chenn...
# exp    dedicated work , innovative idea dynamic chall...
# skill  contribute organization new trend technology \...
# edu    kodaikanal christian college - kodaikanal , ta...
#
# [4 rows x 251 columns]
